# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
filpkart_url ="https://www.flipkart.com/search?q=" + "tv"

# %%
filpkart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(filpkart_url)

# %%
flipkart_page = urlclient.read()

# %%
flipkart_page
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
type(flipkart_page)
# Out:
# bytes

# %%
flipkart_html = bs(flipkart_page, 'html.parser')

# %%
type(flipkart_html)
# Out:
# bs4.BeautifulSoup

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox = flipkart_html.find_all( "div", {"class":"_16PBlm"})

# %%
len(bigbox)
# Out:
# 0

# %%
del bigbox[0:3]

# %%
len(bigbox)
# Out:
# 0

# %%
productlink = 'https://www.flipkart.com' + bigbox[0].div.div.div.a['href']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\tejas\Desktop\Python Teachings\Web_scraping_project\Day 1\1_web_scraping.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tejas/Desktop/Python%20Teachings/Web_scraping_project/Day%201/1_web_scraping.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> productlink = 'https://www.flipkart.com' + bigbox[0].div.div.div.a['href']
#
# IndexError: list index out of range

# %%
for i in bigbox:
    'https://www.flipkart.com' + i.div.div.div.a['href']

# %%
product_request = requests.get(productlink)

# %%
product_html = bs(product_request.text)

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %%
coment_box = product_html.find_all("div",{"class":"_16PBlm"})

# %%
len(coment_box)
# Out:
# 11

# %%
coment_box[0].div.div.div.find_all("p",{"class":"_2-N8zT"})[0].text
# Out:
# 'Classy product'

# %%
for i in coment_box:
    print(i.div.div.div.find_all("p",{"class":"_2-N8zT"})[0].text)
# Out:
# Classy product
# Great product
# Terrific purchase
# Worth every penny
# Brilliant
# Wonderful
# Great product
# Worth the money
# Really Nice
# Awesome
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\tejas\Desktop\Python Teachings\Web_scraping_project\Day 1\1_web_scraping.ipynb Cell 23 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/tejas/Desktop/Python%20Teachings/Web_scraping_project/Day%201/1_web_scraping.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> for i in coment_box:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/tejas/Desktop/Python%20Teachings/Web_scraping_project/Day%201/1_web_scraping.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a>     print(i.div.div.div.find_all("p",{"class":"_2-N8zT"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
coment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
try:
    for i in coment_box:
        print(i.div.div.div.div.text)
except Exception as e:
    print(e)
# Out:
# 5
# 5
# 5
# 5
# 5
# 5
# 5
# 4
# 4
# 5
# 'NoneType' object has no attribute 'div'

# %%
coment_box = product_html.find_all("div",{"class":"col _2wzgFH"})

# %%
coment_box[0].div.div.find_all("div",{"class",""})
# Out:
# []
